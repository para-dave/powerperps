# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sbn
import pandas as pd
from matplotlib.pyplot import figure
from itertools import cycle, islice
from power_perp import everlasting_power_perp_price

# %%
vol = 1.5
drift = 0
funding_period = 1/365
spot = np.arange(1000., 4000., 50.)

# %%
power = 1
payoff = spot ** power / spot[0]**(power-1)
price = everlasting_power_perp_price(spot, funding_period, vol, drift, power) / spot[0]**(power-1)

data = pd.DataFrame({'spot ETH': spot, f'ETH^{power}': payoff, f'ETH^{power} perp price': price}).set_index('spot ETH')
figure(figsize=(12, 9), dpi=80)
ax = sbn.lineplot(data=data)
ax.set_ylabel("value")
ax.set_title(f"Normalized ETH^{power} Perpetual Price vs. Spot Price ({int(vol*100)} vol)")
# Out:
# Text(0.5, 1.0, 'Normalized ETH^1 Perpetual Price vs. Spot Price (150 vol)')

# %%
power = 2
payoff = spot ** power / spot[0]**(power-1)
price = everlasting_power_perp_price(spot, funding_period, vol, drift, power) / spot[0]**(power-1)

data = pd.DataFrame({'spot ETH': spot, f'ETH^{power}': payoff, f'ETH^{power} perp price': price}).set_index('spot ETH')
figure(figsize=(12, 9), dpi=80)
ax = sbn.lineplot(data=data)
ax.set_ylabel("value")
ax.set_title(f"Normalized ETH^{power} Perpetual Price vs. Spot Price ({int(vol*100)} vol)")
# Out:
# Text(0.5, 1.0, 'Normalized ETH^2 Perpetual Price vs. Spot Price (150 vol)')

# %%
power = 3
payoff = spot ** power / spot[0]**(power-1)
price = everlasting_power_perp_price(spot, funding_period, vol, drift, power) / spot[0]**(power-1)

data = pd.DataFrame({'spot ETH': spot, f'ETH^{power}': payoff, f'ETH^{power} perp price': price}).set_index('spot ETH')
figure(figsize=(12, 9), dpi=80)
ax = sbn.lineplot(data=data)
ax.set_ylabel("value")
ax.set_title(f"Normalized ETH^{power} Perpetual Price vs. Spot Price ({int(vol*100)} vol)")
# Out:
# Text(0.5, 1.0, 'Normalized ETH^3 Perpetual Price vs. Spot Price (150 vol)')
